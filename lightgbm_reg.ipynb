# %%
import pandas as pd
from lightgbm import LGBMRegressor
from sklearn.model_selection import TimeSeriesSplit
import optuna
import numpy as np
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
X = pd.read_csv('dataset/X_train.csv').set_index('DELIVERY_START')
X.index = pd.to_datetime(X.index, utc=True).tz_convert(None)
X.head()
# Out:
#                      load_forecast  coal_power_available  gas_power_available  \
# DELIVERY_START
# 2022-01-01 01:00:00        49439.0                3386.0              11487.0
# 2022-01-01 02:00:00        46511.0                3386.0              11487.0
# 2022-01-01 03:00:00        45158.0                3386.0              11487.0
# 2022-01-01 04:00:00        44779.0                3386.0              11487.0
# 2022-01-01 05:00:00        45284.0                3386.0              11487.0
#
#                      nucelear_power_available  wind_power_forecasts_average  \
# DELIVERY_START
# 2022-01-01 01:00:00                   44118.0                        3035.0
# 2022-01-01 02:00:00                   44118.0                        3143.0
# 2022-01-01 03:00:00                   44118.0                        3288.0
# 2022-01-01 04:00:00                   44118.0                        3447.0
# 2022-01-01 05:00:00                   44118.0                        3679.0
#
#                      solar_power_forecasts_average  wind_power_forecasts_std  \
# DELIVERY_START
# 2022-01-01 01:00:00                            0.0                 79.248348
# 2022-01-01 02:00:00                            0.0                 61.776532
# 2022-01-01 03:00:00                            0.0                 44.291112
# 2022-01-01 04:00:00                            0.0                 36.127588
# 2022-01-01 05:00:00                            0.0                 30.983023
#
#                      solar_power_forecasts_std  predicted_spot_price
# DELIVERY_START
# 2022-01-01 01:00:00                        0.0                   NaN
# 2022-01-01 02:00:00                        0.0                   NaN
# 2022-01-01 03:00:00                        0.0                   NaN
# 2022-01-01 04:00:00                        0.0                   NaN
# 2022-01-01 05:00:00                        0.0                   NaN

# %%
y = pd.read_csv('dataset/y_train.csv').set_index('DELIVERY_START')
y.index = pd.to_datetime(y.index, utc=True).tz_convert(None)

# fix outliers
y.loc["2022-04-04 05:00:00"] = (y.loc["2022-04-04 04:00:00"] + y.loc["2022-04-04 07:00:00"]) / 2
y.loc["2022-04-04 06:00:00"] = (y.loc["2022-04-04 04:00:00"] + y.loc["2022-04-04 07:00:00"]) / 2
y.head()
# Out:
#                      spot_id_delta
# DELIVERY_START
# 2022-01-01 01:00:00     -36.874770
# 2022-01-01 02:00:00     -12.643588
# 2022-01-01 03:00:00      -1.950193
# 2022-01-01 04:00:00       1.938272
# 2022-01-01 05:00:00       0.199907

# %%
def create_time_features(df):
    df = df.copy()
    df['dayofmonth'] = df.index.day
    df['dayofweek'] = df.index.dayofweek
    df['hour'] = df.index.hour
    return df

# %%
# initially try using all variables without preprocessing except 'load_forecast' and 'predicted_spot_price' (too many missing points)
X_cols = ['coal_power_available', 'gas_power_available',
       'nucelear_power_available', 'wind_power_forecasts_average',
       'solar_power_forecasts_average', 'wind_power_forecasts_std',
       'solar_power_forecasts_std']

# %%
X[X_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10605 entries, 2022-01-01 01:00:00 to 2023-03-29 21:00:00
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coal_power_available           10604 non-null  float64
#  1   gas_power_available            10604 non-null  float64
#  2   nucelear_power_available       10604 non-null  float64
#  3   wind_power_forecasts_average   10581 non-null  float64
#  4   solar_power_forecasts_average  10581 non-null  float64
#  5   wind_power_forecasts_std       10581 non-null  float64
#  6   solar_power_forecasts_std      10581 non-null  float64
# dtypes: float64(7)
# memory usage: 662.8 KB

# %%
X = X[X_cols].interpolate()
X = create_time_features(X)

# %%
cutoff_date = "2023-03-01"
X_train = X.loc[:cutoff_date]
X_test = X.loc[cutoff_date:]
y_train = y.loc[:cutoff_date]
y_test = y.loc[cutoff_date:]

# %%
scaler = StandardScaler()
scaler.fit(X_train[X_cols])
X_train.loc[:, X_cols] = scaler.transform(X_train[X_cols])
X_test.loc[:, X_cols] = scaler.transform(X_test[X_cols])

# %%
X_train.head()
# Out:
#                      coal_power_available  gas_power_available  \
# DELIVERY_START
# 2022-01-01 01:00:00              1.233632             0.108939
# 2022-01-01 02:00:00              1.233632             0.108939
# 2022-01-01 03:00:00              1.233632             0.108939
# 2022-01-01 04:00:00              1.233632             0.108939
# 2022-01-01 05:00:00              1.233632             0.108939
#
#                      nucelear_power_available  wind_power_forecasts_average  \
# DELIVERY_START
# 2022-01-01 01:00:00                  1.138401                     -0.413766
# 2022-01-01 02:00:00                  1.138401                     -0.380733
# 2022-01-01 03:00:00                  1.138401                     -0.336383
# 2022-01-01 04:00:00                  1.138401                     -0.287751
# 2022-01-01 05:00:00                  1.138401                     -0.216791
#
#                      solar_power_forecasts_average  wind_power_forecasts_std  \
# DELIVERY_START
# 2022-01-01 01:00:00                      -0.705142                 -0.334578
# 2022-01-01 02:00:00                      -0.705142                 -0.470218
# 2022-01-01 03:00:00                      -0.705142                 -0.605963
# 2022-01-01 04:00:00                      -0.705142                 -0.669339
# 2022-01-01 05:00:00                      -0.705142                 -0.709278
#
#                      solar_power_forecasts_std  dayofmonth  dayofweek  hour
# DELIVERY_START
# 2022-01-01 01:00:00                  -0.572204           1          5     1
# 2022-01-01 02:00:00                  -0.572204           1          5     2
# 2022-01-01 03:00:00                  -0.572204           1          5     3
# 2022-01-01 04:00:00                  -0.572204           1          5     4
# 2022-01-01 05:00:00                  -0.572204           1          5     5

# %% [markdown]
# ### playing around

# %%
model = lgb.LGBMRegressor(max_depth=16, learning_rate=0.5, n_estimators=500, colsample_bytree=0.6, reg_lambda=1)
model.fit(X_train, y_train)
pred = model.predict(X_test)
results_df = y_test.copy()
results_df['pred'] = pred
results_df.plot()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000395 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1411
# [LightGBM] [Info] Number of data points in the train set: 9935, number of used features: 10
# [LightGBM] [Info] Start training from score 0.733646
# <Axes: xlabel='DELIVERY_START'>

# %%
train_res = y_train.copy()
train_res['model'] = model.predict(X_train)
train_res.plot()
# Out:
# <Axes: xlabel='DELIVERY_START'>

# %% [markdown]
# ### train model

# %%
tscv = TimeSeriesSplit(n_splits=10, max_train_size=5000, test_size=500)

for train, test in tscv.split(X_train):
    print(f"[{train[0]}, ..., {train[-1]}] [{test[0]}, ..., {test[-1]}]")
# Out:
# [0, ..., 4934] [4935, ..., 5434]
# [435, ..., 5434] [5435, ..., 5934]
# [935, ..., 5934] [5935, ..., 6434]
# [1435, ..., 6434] [6435, ..., 6934]
# [1935, ..., 6934] [6935, ..., 7434]
# [2435, ..., 7434] [7435, ..., 7934]
# [2935, ..., 7934] [7935, ..., 8434]
# [3435, ..., 8434] [8435, ..., 8934]
# [3935, ..., 8934] [8935, ..., 9434]
# [4435, ..., 9434] [9435, ..., 9934]

# %%
def objective(trial):
    tscv = TimeSeriesSplit(n_splits=10, max_train_size=5000, test_size=500)
    params = {
        'learning_rate': trial.suggest_categorical('learning_rate', [0.001, 0.01, 0.05, 0.1]),
        'num_leaves': trial.suggest_categorical('num_leaves', [5, 10, 20, 50]),
        'max_depth': trial.suggest_categorical('max_depth', [5, 7, 10, 15]),
        'min_data_in_leaf': trial.suggest_categorical('min_data_in_leaf', [20, 30, 40, 100]),
        'feature_fraction': trial.suggest_categorical('feature_fraction', [0.5, 0.8, 0.9, 1.0]),
        'bagging_fraction': trial.suggest_categorical('bagging_fraction', [0.8, 0.9, 1.0]),
        'bagging_freq': trial.suggest_categorical('bagging_freq', [0, 1, 2, 5]),
        'lambda_l1': trial.suggest_categorical('lambda_l1', [0, 0.1, 0.5, 1]),
        'lambda_l2': trial.suggest_categorical('lambda_l2', [0, 0.1, 0.5, 1]),
        'n_estimators': trial.suggest_categorical('n_estimators', [100, 200, 500]),
        'verbose': -1
    }
    
    model = lgb.LGBMRegressor(**params)
    
    mse_arr = []
    for train_idx, test_idx in tscv.split(X_train):
        X_train_cv = X_train.iloc[train_idx]
        X_test_cv = X_train.iloc[test_idx]
        y_train_cv = y_train.iloc[train_idx]
        y_test_cv = y_train.iloc[test_idx]
    
        model.fit(X_train_cv, y_train_cv)
        pred = model.predict(X_test_cv)
        mse = mean_squared_error(y_test_cv, pred)
        mse_arr.append(mse)
        
    return np.mean(mse_arr)

# %%
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=10)

print("Number of finished trials: {}".format(len(study.trials)))
print("Best trial:")

trial = study.best_trial

print("  Value: {}".format(trial.value))
print("  Params: ")

for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-11-21 22:47:38,732] A new study created in memory with name: no-name-af20e19b-a715-4af0-b68a-ca69e20541ed
# [I 2024-11-21 22:47:40,640] Trial 0 finished with value: 1336.9736515070645 and parameters: {'learning_rate': 0.1, 'num_leaves': 5, 'max_depth': 5, 'min_data_in_leaf': 30, 'feature_fraction': 0.8, 'bagging_fraction': 0.9, 'bagging_freq': 1, 'lambda_l1': 0.1, 'lambda_l2': 0, 'n_estimators': 200}. Best is trial 0 with value: 1336.9736515070645.
# [I 2024-11-21 22:47:46,247] Trial 1 finished with value: 1321.8625555865594 and parameters: {'learning_rate': 0.05, 'num_leaves': 50, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.9, 'bagging_fraction': 0.8, 'bagging_freq': 0, 'lambda_l1': 0, 'lambda_l2': 1, 'n_estimators': 100}. Best is trial 1 with value: 1321.8625555865594.
# [I 2024-11-21 22:47:48,694] Trial 2 finished with value: 1197.0584648233537 and parameters: {'learning_rate': 0.001, 'num_leaves': 20, 'max_depth': 10, 'min_data_in_leaf': 100, 'feature_fraction': 0.8, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.5, 'n_estimators': 100}. Best is trial 2 with value: 1197.0584648233537.
# [I 2024-11-21 22:47:49,449] Trial 3 finished with value: 1254.776203171129 and parameters: {'learning_rate': 0.05, 'num_leaves': 5, 'max_depth': 5, 'min_data_in_leaf': 20, 'feature_fraction': 1.0, 'bagging_fraction': 0.9, 'bagging_freq': 0, 'lambda_l1': 1, 'lambda_l2': 0.5, 'n_estimators': 100}. Best is trial 2 with value: 1197.0584648233537.
# [I 2024-11-21 22:47:57,756] Trial 4 finished with value: 1209.709038561798 and parameters: {'learning_rate': 0.001, 'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 30, 'feature_fraction': 0.8, 'bagging_fraction': 0.9, 'bagging_freq': 0, 'lambda_l1': 0.1, 'lambda_l2': 0.5, 'n_estimators': 500}. Best is trial 2 with value: 1197.0584648233537.
# [I 2024-11-21 22:47:59,180] Trial 5 finished with value: 1251.002569036939 and parameters: {'learning_rate': 0.05, 'num_leaves': 10, 'max_depth': 7, 'min_data_in_leaf': 30, 'feature_fraction': 1.0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'lambda_l1': 0, 'lambda_l2': 1, 'n_estimators': 100}. Best is trial 2 with value: 1197.0584648233537.
# [I 2024-11-21 22:48:07,468] Trial 6 finished with value: 1409.5757312926994 and parameters: {'learning_rate': 0.05, 'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 40, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 1, 'lambda_l1': 0.5, 'lambda_l2': 0.5, 'n_estimators': 200}. Best is trial 2 with value: 1197.0584648233537.
# [I 2024-11-21 22:48:11,949] Trial 7 finished with value: 1421.6886373522834 and parameters: {'learning_rate': 0.1, 'num_leaves': 20, 'max_depth': 7, 'min_data_in_leaf': 40, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'bagging_freq': 1, 'lambda_l1': 0.5, 'lambda_l2': 1, 'n_estimators': 200}. Best is trial 2 with value: 1197.0584648233537.
# [I 2024-11-21 22:48:20,584] Trial 8 finished with value: 1381.436170568318 and parameters: {'learning_rate': 0.05, 'num_leaves': 20, 'max_depth': 5, 'min_data_in_leaf': 30, 'feature_fraction': 1.0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'lambda_l1': 1, 'lambda_l2': 0, 'n_estimators': 500}. Best is trial 2 with value: 1197.0584648233537.
# [I 2024-11-21 22:48:22,871] Trial 9 finished with value: 1294.5972859186122 and parameters: {'learning_rate': 0.05, 'num_leaves': 20, 'max_depth': 10, 'min_data_in_leaf': 100, 'feature_fraction': 0.8, 'bagging_fraction': 0.9, 'bagging_freq': 1, 'lambda_l1': 0.5, 'lambda_l2': 0.1, 'n_estimators': 100}. Best is trial 2 with value: 1197.0584648233537.
# [I 2024-11-21 22:48:24,132] Trial 10 finished with value: 1195.1307273894436 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 100, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'n_estimators': 100}. Best is trial 10 with value: 1195.1307273894436.
# [I 2024-11-21 22:48:25,406] Trial 11 finished with value: 1195.1307273894436 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 100, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'n_estimators': 100}. Best is trial 10 with value: 1195.1307273894436.
# [I 2024-11-21 22:48:26,674] Trial 12 finished with value: 1195.1307273894436 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 100, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'n_estimators': 100}. Best is trial 10 with value: 1195.1307273894436.
# [I 2024-11-21 22:48:27,999] Trial 13 finished with value: 1202.2379691067813 and parameters: {'learning_rate': 0.01, 'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 100, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'n_estimators': 100}. Best is trial 10 with value: 1195.1307273894436.
# [I 2024-11-21 22:48:34,135] Trial 14 finished with value: 1197.3734564790398 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 100, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 10 with value: 1195.1307273894436.
# [I 2024-11-21 22:48:35,402] Trial 15 finished with value: 1195.1307273894436 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 100, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'n_estimators': 100}. Best is trial 10 with value: 1195.1307273894436.
# [I 2024-11-21 22:48:36,659] Trial 16 finished with value: 1202.2379691067813 and parameters: {'learning_rate': 0.01, 'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 100, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'n_estimators': 100}. Best is trial 10 with value: 1195.1307273894436.
# [I 2024-11-21 22:48:37,926] Trial 17 finished with value: 1195.137753055236 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 100, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 1, 'lambda_l2': 0.1, 'n_estimators': 100}. Best is trial 10 with value: 1195.1307273894436.
# [I 2024-11-21 22:48:44,089] Trial 18 finished with value: 1193.1084820480369 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:48:47,513] Trial 19 finished with value: 1197.242446117095 and parameters: {'learning_rate': 0.001, 'num_leaves': 5, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.9, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:48:53,704] Trial 20 finished with value: 1253.3443564232641 and parameters: {'learning_rate': 0.01, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:48:59,971] Trial 21 finished with value: 1193.1084820480369 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:49:06,140] Trial 22 finished with value: 1193.1084820480369 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:49:12,354] Trial 23 finished with value: 1193.1084820480369 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:49:18,381] Trial 24 finished with value: 1463.328800894894 and parameters: {'learning_rate': 0.1, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:49:24,521] Trial 25 finished with value: 1193.1084820480369 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:49:31,250] Trial 26 finished with value: 1194.9293088194568 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 0.8, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:49:34,625] Trial 27 finished with value: 1197.242446117095 and parameters: {'learning_rate': 0.001, 'num_leaves': 5, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.9, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'lambda_l1': 0, 'lambda_l2': 0, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:50:02,548] Trial 28 finished with value: 1203.925790964251 and parameters: {'learning_rate': 0.001, 'num_leaves': 50, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 5, 'lambda_l1': 0, 'lambda_l2': 1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:50:03,971] Trial 29 finished with value: 1329.7651366338728 and parameters: {'learning_rate': 0.1, 'num_leaves': 5, 'max_depth': 7, 'min_data_in_leaf': 40, 'feature_fraction': 0.8, 'bagging_fraction': 1.0, 'bagging_freq': 1, 'lambda_l1': 0, 'lambda_l2': 0, 'n_estimators': 200}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:50:10,488] Trial 30 finished with value: 1447.214477493832 and parameters: {'learning_rate': 0.1, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 0.8, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:50:16,676] Trial 31 finished with value: 1193.1084820480369 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:50:22,839] Trial 32 finished with value: 1193.1084820480369 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:50:28,798] Trial 33 finished with value: 1193.1084820480369 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:50:34,947] Trial 34 finished with value: 1193.1084820480369 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:51:02,786] Trial 35 finished with value: 1203.197237426709 and parameters: {'learning_rate': 0.001, 'num_leaves': 50, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.9, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.5, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:51:12,121] Trial 36 finished with value: 1272.2787691514854 and parameters: {'learning_rate': 0.01, 'num_leaves': 20, 'max_depth': 5, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'bagging_freq': 0, 'lambda_l1': 1, 'lambda_l2': 1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:51:14,709] Trial 37 finished with value: 1201.983452824308 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 30, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 5, 'lambda_l1': 0, 'lambda_l2': 0.5, 'n_estimators': 200}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:51:43,366] Trial 38 finished with value: 1195.2887574620192 and parameters: {'learning_rate': 0.001, 'num_leaves': 50, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 2, 'lambda_l1': 0.5, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:51:46,790] Trial 39 finished with value: 1201.9763083635148 and parameters: {'learning_rate': 0.001, 'num_leaves': 5, 'max_depth': 7, 'min_data_in_leaf': 40, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 1, 'lambda_l1': 0, 'lambda_l2': 1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:51:49,294] Trial 40 finished with value: 1300.2957038297925 and parameters: {'learning_rate': 0.05, 'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 30, 'feature_fraction': 0.8, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'lambda_l1': 0, 'lambda_l2': 0.5, 'n_estimators': 200}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:51:55,494] Trial 41 finished with value: 1193.1084820480369 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:52:01,642] Trial 42 finished with value: 1193.1084820480369 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:52:07,818] Trial 43 finished with value: 1193.1084820480369 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:52:19,602] Trial 44 finished with value: 1197.5720290747201 and parameters: {'learning_rate': 0.001, 'num_leaves': 20, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0.5, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:52:26,131] Trial 45 finished with value: 1348.161452689122 and parameters: {'learning_rate': 0.05, 'num_leaves': 10, 'max_depth': 7, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 0.8, 'bagging_freq': 2, 'lambda_l1': 1, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:52:32,310] Trial 46 finished with value: 1205.6854324576686 and parameters: {'learning_rate': 0.001, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 40, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 1, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:52:34,899] Trial 47 finished with value: 1363.8980290159502 and parameters: {'learning_rate': 0.1, 'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 20, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 200}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:52:46,749] Trial 48 finished with value: 1208.901440025358 and parameters: {'learning_rate': 0.001, 'num_leaves': 20, 'max_depth': 15, 'min_data_in_leaf': 30, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'lambda_l1': 0.5, 'lambda_l2': 0, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# [I 2024-11-21 22:52:52,900] Trial 49 finished with value: 1253.3443564232641 and parameters: {'learning_rate': 0.01, 'num_leaves': 10, 'max_depth': 15, 'min_data_in_leaf': 20, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 2, 'lambda_l1': 0, 'lambda_l2': 0.1, 'n_estimators': 500}. Best is trial 18 with value: 1193.1084820480369.
# Number of finished trials: 50
# Best trial:
#   Value: 1193.1084820480369
#   Params:
#     learning_rate: 0.001
#     num_leaves: 10
#     max_depth: 15
#     min_data_in_leaf: 20
#     feature_fraction: 0.5
#     bagging_fraction: 1.0
#     bagging_freq: 2
#     lambda_l1: 0
#     lambda_l2: 0.1
#     n_estimators: 500

# %% [markdown]
# ### Test model with found hyperparams

# %%
model = lgb.LGBMRegressor(**trial.params)

# %%
model.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
results_df = y_test.copy()
results_df['pred'] = pred

# %%
results_df.plot()
# Out:
# <Axes: xlabel='DELIVERY_START'>
